# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_excel('GLCM_extended_dataset_31-01-2023.xlsx')
df.head(3)
# Out:
#    dissimilarity_0  dissimilarity_45  dissimilarity_90  dissimilarity_135  \
# 0         3.678102          6.468785          6.257544           6.491273
# 1         4.396102         12.171347         13.892070          13.380560
# 2         3.334305          4.433875          4.334105           4.405370
#
#    correlation_0  correlation_45  correlation_90  correlation_135  \
# 0       0.915573        0.018493        0.075505         0.021779
# 1       0.959208        0.717372        0.645733         0.672928
# 2       0.787040        0.602248        0.619119         0.608713
#
#    homogeneity_0  homogeneity_45  ...     ASM_0    ASM_45    ASM_90   ASM_135  \
# 0       0.275196        0.202223  ...  0.003788  0.002980  0.003008  0.002954
# 1       0.354369        0.256529  ...  0.003142  0.002297  0.002205  0.002255
# 2       0.280222        0.224585  ...  0.003641  0.002988  0.003047  0.003001
#
#    energy_0  energy_45  energy_90  energy_135  label       fname
# 0  0.061551   0.054587   0.054849    0.054355      2       1.png
# 1  0.056056   0.047928   0.046956    0.047492      2  10.jpg.png
# 2  0.060337   0.054659   0.055196    0.054781      2      10.png
#
# [3 rows x 26 columns]

# %%
df.drop('fname',axis=1,inplace=True)

# %%
df['label'].unique()
# Out:
# array([2, 0, 1], dtype=int64)

# %%
df_data_1=df.loc[df['label']==0]

# %%
df_data_2=df.loc[df['label']==1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3253 entries, 0 to 3252
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dissimilarity_0    3253 non-null   float64
#  1   dissimilarity_45   3253 non-null   float64
#  2   dissimilarity_90   3253 non-null   float64
#  3   dissimilarity_135  3253 non-null   float64
#  4   correlation_0      3253 non-null   float64
#  5   correlation_45     3253 non-null   float64
#  6   correlation_90     3253 non-null   float64
#  7   correlation_135    3253 non-null   float64
#  8   homogeneity_0      3253 non-null   float64
#  9   homogeneity_45     3253 non-null   float64
#  10  homogeneity_90     3253 non-null   float64
#  11  homogeneity_135    3253 non-null   float64
#  12  contrast_0         3253 non-null   float64
#  13  contrast_45        3253 non-null   float64
#  14  contrast_90        3253 non-null   float64
#  15  contrast_135       3253 non-null   float64
#  16  ASM_0              3253 non-null   float64
#  17  ASM_45             3253 non-null   float64
#  18  ASM_90             3253 non-null   float64
#  19  ASM_135            3253 non-null   float64
#  20  energy_0           3253 non-null   float64
#  21  energy_45          3253 non-null   float64
#  22  energy_90          3253 non-null   float64
#  23  energy_135         3253 non-null   float64
#  24  label              3253 non-null   int64
# dtypes: float64(24), int64(1)
# memory usage: 635.5 KB

# %%
df_data=pd.concat([df_data_1,df_data_2],ignore_index=True)

# %%
df_data
# Out:
#       dissimilarity_0  dissimilarity_45  dissimilarity_90  dissimilarity_135  \
# 0           17.075186         19.076014         17.000596          19.423916
# 1           26.067186         30.933699         27.184842          30.684157
# 2           22.778915         27.697635         25.499649          27.798001
# 3           22.757153         27.005138         24.785158          27.172473
# 4           24.228373         30.622290         27.992456          30.419412
# ...               ...               ...               ...                ...
# 2684        11.169492         17.211571         15.906351          16.981243
# 2685        11.221864         17.026429         15.829088          17.246516
# 2686         8.783220         14.184403         13.661895          14.182081
# 2687         8.901288         13.915365         13.410982          13.834354
# 2688         7.827186         11.332418         10.374491          11.275514
#
#       correlation_0  correlation_45  correlation_90  correlation_135  \
# 0          0.312974        0.194221        0.329614         0.165452
# 1          0.529364        0.410559        0.508984         0.418465
# 2          0.492719        0.338570        0.420112         0.335745
# 3          0.404545        0.234620        0.327899         0.226174
# 4          0.462041        0.215050        0.311135         0.227051
# ...             ...             ...             ...              ...
# 2684       0.634442        0.062414        0.296617         0.072867
# 2685       0.667032        0.186955        0.400760         0.183424
# 2686       0.737062        0.186100        0.288175         0.180899
# 2687       0.692474        0.221799        0.349834         0.239547
# 2688       0.577229       -0.028907        0.255772        -0.013765
#
#       homogeneity_0  homogeneity_45  ...  contrast_135     ASM_0    ASM_45  \
# 0          0.095627        0.075057  ...    689.053632  0.000371  0.000340
# 1          0.092598        0.065083  ...   1961.653892  0.000152  0.000123
# 2          0.095726        0.065100  ...   1482.574043  0.000238  0.000190
# 3          0.097751        0.068675  ...   1458.874824  0.000312  0.000265
# 4          0.088464        0.056560  ...   1744.387458  0.000258  0.000212
# ...             ...             ...  ...           ...       ...       ...
# 2684       0.189892        0.129753  ...    809.266434  0.001882  0.001330
# 2685       0.138227        0.089316  ...    696.134115  0.000922  0.000683
# 2686       0.191747        0.128276  ...    626.598958  0.001416  0.001068
# 2687       0.165122        0.109499  ...    539.839985  0.001276  0.001030
# 2688       0.181296        0.144669  ...    368.425711  0.001787  0.001615
#
#         ASM_90   ASM_135  energy_0  energy_45  energy_90  energy_135  label
# 0     0.000379  0.000337  0.019250   0.018446   0.019469    0.018363      0
# 1     0.000143  0.000124  0.012329   0.011099   0.011949    0.011146      0
# 2     0.000209  0.000189  0.015434   0.013779   0.014463    0.013744      0
# 3     0.000285  0.000263  0.017673   0.016285   0.016896    0.016231      0
# 4     0.000232  0.000213  0.016064   0.014544   0.015231    0.014591      0
# ...        ...       ...       ...        ...        ...         ...    ...
# 2684  0.001345  0.001324  0.043382   0.036465   0.036678    0.036391      1
# 2685  0.000703  0.000679  0.030367   0.026144   0.026521    0.026052      1
# 2686  0.001070  0.001067  0.037635   0.032673   0.032705    0.032658      1
# 2687  0.001034  0.001029  0.035718   0.032087   0.032158    0.032083      1
# 2688  0.001629  0.001601  0.042277   0.040192   0.040358    0.040013      1
#
# [2689 rows x 25 columns]

# %%
#1
sns.scatterplot(x='contrast_45',y='contrast_90',data=df_data)
# Out:
# <Axes: xlabel='contrast_45', ylabel='contrast_90'>

# %%
#2
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse

# %%
regr=LinearRegression()

# %%
df.columns
# Out:
# Index(['dissimilarity_0', 'dissimilarity_45', 'dissimilarity_90',
#        'dissimilarity_135', 'correlation_0', 'correlation_45',
#        'correlation_90', 'correlation_135', 'homogeneity_0', 'homogeneity_45',
#        'homogeneity_90', 'homogeneity_135', 'contrast_0', 'contrast_45',
#        'contrast_90', 'contrast_135', 'ASM_0', 'ASM_45', 'ASM_90', 'ASM_135',
#        'energy_0', 'energy_45', 'energy_90', 'energy_135', 'label'],
#       dtype='object')

# %%
columns=list(df.columns.values)
columns.remove('contrast_45')
dependent_var=df['contrast_90'].values.reshape(-1,1)

# %%
for i in columns:
    independent_var=df[i].values.reshape(-1,1)
    X_train,X_test,y_train,y_test=train_test_split(dependent_var,independent_var,test_size=0.3)
    regr.fit(X_train,y_train)
    prediction=regr.predict(X_test)
    print(mse(prediction,y_test))
# Out:
# 7.753696582373568
# 6.849660061841238
# 4.273403743564849
# 6.78845571351685
# 0.013218698128488603
# 0.034566091302863595
# 0.030763088866434463
# 0.03968186437693683
# 0.0015507760629989585
# 0.0008570084612764916
# 0.0008083502227478372
# 0.0011118689560354492
# 34814.290666423236
# 9.91714547176697e-27
# 4301.993790724989
# 1.2473220452684315e-05
# 2.9007271880234096e-07
# 3.271094088834278e-07
# 2.1624422452582533e-07
# 6.177361466882058e-05
# 5.127574080243261e-05
# 5.609077133185266e-05
# 5.281120203515668e-05
# 0.46027239685665366

# %%
#4
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
logregr=LogisticRegression()

# %%
X_train,X_test,y_train,y_test=train_test_split(df_data.drop('label',axis=1),df_data['label'],test_size=0.3)
logregr.fit(X_train,y_train)
prediction=logregr.predict(X_test)
# Out:
# C:\Users\KrishnaMohan\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy_score(y_test,prediction)
# Out:
# 0.7447335811648079

# %%
#5 knn regressor
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor(n_neighbors=5)
for i in columns:
    independent_var=df[i].values.reshape(-1,1)
    X_train,X_test,y_train,y_test=train_test_split(dependent_var,independent_var,test_size=0.3)
    knn.fit(X_train,y_train)
    prediction=knn.predict(X_test)
    print(mse(prediction,y_test))
# Out:
# 10.807391102228031
# 5.48826805561143
# 4.023591200175087
# 5.62485282822023
# 0.016346008116442486
# 0.042511490550732826
# 0.03148266823097695
# 0.04396682047436658
# 0.0012274375864833901
# 0.0006164808286300177
# 0.0006480703558701678
# 0.0006979320634186091
# 33213.21520309346
# 91.44797779594504
# 4735.614041920254
# 7.138793660463962e-07
# 4.4999439423634996e-07
# 1.2432112784979698e-07
# 8.671501025084287e-06
# 0.0001505171003963765
# 4.373530264315077e-05
# 4.7339658054066325e-05
# 3.739744389869551e-05
# 0.4934016393442623

# %%
#regression tree
data_2=df_data.drop('label',axis=1)
from sklearn.tree import DecisionTreeRegressor   
regressor = DecisionTreeRegressor(random_state = 0)  
X_train,X_test,y_train,y_test=train_test_split(data_2.drop('energy_135',axis=1),data_2['energy_135'],test_size=0.3)
regressor.fit(X_train, y_train) 
prediction=regressor.predict(X_test)
print(mse(prediction,y_test))
# Out:
# 5.841646937714015e-09
